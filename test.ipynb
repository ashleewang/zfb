# %%
import pandas as pds 
dirstr=r'C:\Users\DELL\Desktop\a.csv'
dirstr
# Out:
# 'C:\\Users\\DELL\\Desktop\\a.csv'

# %%
zhifubao=pds.read_csv(dirstr,encoding='gbk',skiprows=4)
zhifubao=zhifubao.drop(zhifubao.tail(7).index)
zhifubao
# Out:
# 20-07-03 16:37:53
# 29                         T200P1099270402202502045\t  2020-07-03 13:35:48
# ..                                                ...                   ...
# 59                         T200P1079013664307502045\t  2020-06-21 17:33:59
# 60             351266000048210001112097350001177239\t  2020-06-20 16:10:04
# 61        071266000048180000T6172818320200620130434\t  2020-06-20 13:04:36
# 62                         T200P1076785697105502045\t  2020-06-20 13:03:08
# 63                         T200P1076594914197502045\t  2020-06-20 11:32:46
# 64                          15925606898002740880180\t  2020-06-19 17:58:09
# 65                          SA200710120061917530204\t  2020-06-19 17:53:27
# 66          bd_48d199f398ec4a6f905402fa3c3036ad-493\t  2020-06-19 17:39:11
# 67                             MLXZFV38XJa0        \t  2020-06-19 16:05:21
# 68                         T200P1074691587111502045\t  2020-06-19 11:06:27
# ...
